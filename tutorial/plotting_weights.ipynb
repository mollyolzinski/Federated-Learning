# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npz file
npz_file = np.load('round-3-weights.npz')

# Display the contents of the .npz file
print(npz_file.files)
# Out:
# ['arr_0', 'arr_1']

# %%
i_class = 1
coefs = npz_file['arr_0'][i_class, :].reshape(28, 28)
intercept = npz_file['arr_1'][i_class]

print(f'intercept: {intercept}')

plt.imshow(coefs)
plt.colorbar()
# Out:
# intercept: 1.6927097183224549e-06
